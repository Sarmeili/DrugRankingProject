# %%
import pandas as pd
ctrp_ranker = pd.read_csv('..\data\ctrp_drugranker\cmpd_id_name_group_smiles.txt', sep = '\t')
ctrp_ranker
# Out:
#      master_cpd_id                       cpd_name cpd_status  \
# 0             1788                          CIL55      probe
# 1             3588                        BRD4132      probe
# 2            12877                        BRD6340      probe
# 3            17712                          ML006      probe
# 4            18311            Bax channel blocker      probe
# ..             ...                            ...        ...
# 540         688975                       avicin D      probe
# 541         689136  BRD9876:MK-1775 (4:1 mol/mol)      probe
# 542         689506                  BRD-K30748066      probe
# 543         705300                     linsitinib   clinical
# 544         710154                         AT-406      probe
#
#                                             cpd_smiles
# 0                CN(C)CCNC(=O)c1cc2CSc3cc(Cl)ccc3-c2s1
# 1    CC(C)N1C(=O)S\C(=C\c2ccc(Sc3nc4ccccc4[nH]3)o2)...
# 2              C(Cn1c2ccccc2c2ccccc12)c1nc2ccccc2[nH]1
# 3             C1CN(CCO1)c1nnc(-c2ccccc2)c(n1)-c1ccccc1
# 4            OC(CN1CCNCC1)Cn1c2ccc(Br)cc2c2cc(Br)ccc12
# ..                                                 ...
# 540  CC1O[C@@H](OCC2O[C@@H](O[C@H]3CC[C@@]4(C)C(CC[...
# 541  CC(C)(C)c1ccc2cc(C#N)c(cc2c1)C#N.CN1CCN(CC1)c1...
# 542      Cc1c(sc(=O)n1C)-c1ccnc(Nc2ccc(cc2)N2CCNCC2)n1
# 543  CC1(O)CC(C1)c2nc(c3ccc4ccc(nc4c3)c5ccccc5)c6c(...
# 544  CNC(C)C(=O)NC1CN(CCC2CCC(N2C1=O)C(=O)NC(c3cccc...
#
# [545 rows x 4 columns]

# %%
ctrp_target = pd.read_excel('..\data\CTRPv2.0._INFORMER_SET.xlsx')
target = ctrp_target[['master_cpd_id', 'gene_symbol_of_protein_target']]

# %%
target
# Out:
#      master_cpd_id gene_symbol_of_protein_target
# 0             1788                           NaN
# 1             3588                           NaN
# 2            12877                           NaN
# 3            17712                         S1PR3
# 4            18311                           BAX
# ..             ...                           ...
# 540         688975                           NaN
# 541         689136                          WEE1
# 542         689506                          CDK9
# 543         705300                    IGF1R;INSR
# 544         710154                          XIAP
#
# [545 rows x 2 columns]

# %%
target.set_index('master_cpd_id').reindex(ctrp_ranker['master_cpd_id'])
# Out:
#               gene_symbol_of_protein_target
# master_cpd_id
# 1788                                    NaN
# 3588                                    NaN
# 12877                                   NaN
# 17712                                 S1PR3
# 18311                                   BAX
# ...                                     ...
# 688975                                  NaN
# 689136                                 WEE1
# 689506                                 CDK9
# 705300                           IGF1R;INSR
# 710154                                 XIAP
#
# [545 rows x 1 columns]

# %%
ctrp_ranker['pro_target'] = None

# %%
ctrp_ranker['pro_target'] = list(target.set_index('master_cpd_id').reindex(ctrp_ranker['master_cpd_id'])['gene_symbol_of_protein_target'])

# %%
ctrp_ranker
# Out:
#      master_cpd_id                       cpd_name cpd_status  \
# 0             1788                          CIL55      probe
# 1             3588                        BRD4132      probe
# 2            12877                        BRD6340      probe
# 3            17712                          ML006      probe
# 4            18311            Bax channel blocker      probe
# ..             ...                            ...        ...
# 540         688975                       avicin D      probe
# 541         689136  BRD9876:MK-1775 (4:1 mol/mol)      probe
# 542         689506                  BRD-K30748066      probe
# 543         705300                     linsitinib   clinical
# 544         710154                         AT-406      probe
#
#                                             cpd_smiles  pro_target
# 0                CN(C)CCNC(=O)c1cc2CSc3cc(Cl)ccc3-c2s1         NaN
# 1    CC(C)N1C(=O)S\C(=C\c2ccc(Sc3nc4ccccc4[nH]3)o2)...         NaN
# 2              C(Cn1c2ccccc2c2ccccc12)c1nc2ccccc2[nH]1         NaN
# 3             C1CN(CCO1)c1nnc(-c2ccccc2)c(n1)-c1ccccc1       S1PR3
# 4            OC(CN1CCNCC1)Cn1c2ccc(Br)cc2c2cc(Br)ccc12         BAX
# ..                                                 ...         ...
# 540  CC1O[C@@H](OCC2O[C@@H](O[C@H]3CC[C@@]4(C)C(CC[...         NaN
# 541  CC(C)(C)c1ccc2cc(C#N)c(cc2c1)C#N.CN1CCN(CC1)c1...        WEE1
# 542      Cc1c(sc(=O)n1C)-c1ccnc(Nc2ccc(cc2)N2CCNCC2)n1        CDK9
# 543  CC1(O)CC(C1)c2nc(c3ccc4ccc(nc4c3)c5ccccc5)c6c(...  IGF1R;INSR
# 544  CNC(C)C(=O)NC1CN(CCC2CCC(N2C1=O)C(=O)NC(c3cccc...        XIAP
#
# [545 rows x 5 columns]

# %%
pp_ctrp = ctrp_ranker.dropna(axis=0)
pp_ctrp
# Out:
#      master_cpd_id                       cpd_name cpd_status  \
# 3            17712                          ML006      probe
# 4            18311            Bax channel blocker      probe
# 6            23151                      tretinoin        FDA
# 8            24173                      phloretin      probe
# 9            24197                    thalidomide        FDA
# ..             ...                            ...        ...
# 539         688962       PF-4800567 hydrochloride      probe
# 541         689136  BRD9876:MK-1775 (4:1 mol/mol)      probe
# 542         689506                  BRD-K30748066      probe
# 543         705300                     linsitinib   clinical
# 544         710154                         AT-406      probe
#
#                                             cpd_smiles      pro_target
# 3             C1CN(CCO1)c1nnc(-c2ccccc2)c(n1)-c1ccccc1           S1PR3
# 4            OC(CN1CCNCC1)Cn1c2ccc(Br)cc2c2cc(Br)ccc12             BAX
# 6             CC(=CC=CC(=CC(=O)O)C)C=CC1=C(C)CCCC1(C)C  RARA;RARB;RARG
# 8                    Oc1ccc(CCC(=O)c2c(O)cc(O)cc2O)cc1          SLC5A1
# 9                  O=C1N(C2CCC(=O)NC2=O)C(=O)c2ccccc12            CRBN
# ..                                                 ...             ...
# 539           Nc1ncnc2n(nc(COc3cccc(Cl)c3)c12)C1CCOCC1   CSNK1D;CSNK1E
# 541  CC(C)(C)c1ccc2cc(C#N)c(cc2c1)C#N.CN1CCN(CC1)c1...            WEE1
# 542      Cc1c(sc(=O)n1C)-c1ccnc(Nc2ccc(cc2)N2CCNCC2)n1            CDK9
# 543  CC1(O)CC(C1)c2nc(c3ccc4ccc(nc4c3)c5ccccc5)c6c(...      IGF1R;INSR
# 544  CNC(C)C(=O)NC1CN(CCC2CCC(N2C1=O)C(=O)NC(c3cccc...            XIAP
#
# [415 rows x 5 columns]

# %%
x
# Out:
#      level_0  level_1      0
# 0          3        0  S1PR3
# 1          4        0    BAX
# 2          6        0   RARA
# 3          6        1   RARB
# 4          6        2   RARG
# ..       ...      ...    ...
# 868      541        0   WEE1
# 869      542        0   CDK9
# 870      543        0  IGF1R
# 871      543        1   INSR
# 872      544        0   XIAP
#
# [873 rows x 3 columns]

# %%
x = pp_ctrp['pro_target'].str.split(';', expand=True).stack().reset_index()
l = pp_ctrp.reindex(x['level_0']) 
l['prot_target'] = list(x[0])

# %%
l = l.drop('pro_target', axis = 1)

# %%
l
# Out:
#          master_cpd_id                       cpd_name cpd_status  \
# level_0
# 3                17712                          ML006      probe
# 4                18311            Bax channel blocker      probe
# 6                23151                      tretinoin        FDA
# 6                23151                      tretinoin        FDA
# 6                23151                      tretinoin        FDA
# ...                ...                            ...        ...
# 541             689136  BRD9876:MK-1775 (4:1 mol/mol)      probe
# 542             689506                  BRD-K30748066      probe
# 543             705300                     linsitinib   clinical
# 543             705300                     linsitinib   clinical
# 544             710154                         AT-406      probe
#
#                                                 cpd_smiles prot_target
# level_0
# 3                 C1CN(CCO1)c1nnc(-c2ccccc2)c(n1)-c1ccccc1       S1PR3
# 4                OC(CN1CCNCC1)Cn1c2ccc(Br)cc2c2cc(Br)ccc12         BAX
# 6                 CC(=CC=CC(=CC(=O)O)C)C=CC1=C(C)CCCC1(C)C        RARA
# 6                 CC(=CC=CC(=CC(=O)O)C)C=CC1=C(C)CCCC1(C)C        RARB
# 6                 CC(=CC=CC(=CC(=O)O)C)C=CC1=C(C)CCCC1(C)C        RARG
# ...                                                    ...         ...
# 541      CC(C)(C)c1ccc2cc(C#N)c(cc2c1)C#N.CN1CCN(CC1)c1...        WEE1
# 542          Cc1c(sc(=O)n1C)-c1ccnc(Nc2ccc(cc2)N2CCNCC2)n1        CDK9
# 543      CC1(O)CC(C1)c2nc(c3ccc4ccc(nc4c3)c5ccccc5)c6c(...       IGF1R
# 543      CC1(O)CC(C1)c2nc(c3ccc4ccc(nc4c3)c5ccccc5)c6c(...        INSR
# 544      CNC(C)C(=O)NC1CN(CCC2CCC(N2C1=O)C(=O)NC(c3cccc...        XIAP
#
# [873 rows x 5 columns]

# %%
ppi_data = pd.read_csv('../data/9606.protein.info.v12.0.txt', sep = '\t')
ppi_data
# Out:
#          #string_protein_id preferred_name  protein_size  \
# 0      9606.ENSP00000000233           ARF5           180
# 1      9606.ENSP00000000412           M6PR           277
# 2      9606.ENSP00000001008          FKBP4           459
# 3      9606.ENSP00000001146        CYP26B1           512
# 4      9606.ENSP00000002125        NDUFAF7           441
# ...                     ...            ...           ...
# 19694  9606.ENSP00000501254        ALDH3B2           385
# 19695  9606.ENSP00000501259        FAM163B           166
# 19696  9606.ENSP00000501265           NWD1          1432
# 19697  9606.ENSP00000501277           LDB1           411
# 19698  9606.ENSP00000501317           RFX7          1460
#
#                                               annotation
# 0      ADP-ribosylation factor 5; GTP-binding protein...
# 1      Cation-dependent mannose-6-phosphate receptor;...
# 2      Peptidyl-prolyl cis-trans isomerase FKBP4, N-t...
# 3      Cytochrome P450 26B1; Involved in the metaboli...
# 4      Protein arginine methyltransferase NDUFAF7, mi...
# ...                                                  ...
# 19694  Aldehyde dehydrogenase family 3 member B2; Oxi...
# 19695  Protein FAM163B; Family with sequence similari...
# 19696  NACHT domain- and WD repeat-containing protein...
# 19697  LIM domain-binding protein 1; Binds to the LIM...
# 19698  DNA-binding protein RFX7; Regulatory factor X7...
#
# [19699 rows x 4 columns]

# %%
ppi_data = ppi_data.set_index('preferred_name')

# %%
df['col2'].isnull().values.any()

# %%
l['string'] = list(ppi_data.reindex(l['prot_target'])['#string_protein_id'])

# %%
l[l['string'].isnull()]
# Out:
#          master_cpd_id         cpd_name cpd_status  \
# level_0
# 10               25036         gossypol   clinical
# 43               44511  pyrazolanthrone      probe
# 178             411731     SID 26681509      probe
# 207             411869     oligomycin A      probe
# 452             660319      elocalcitol   clinical
#
#                                                 cpd_smiles prot_target string
# level_0
# 10       CC(C)c1c(O)c(O)c(C=O)c2c(O)c(c(C)cc12)-c1c(C)c...        LDHB    NaN
# 43                          O=C1c2ccccc2-c2n[nH]c3cccc1c23      MAPK10    NaN
# 178      CCc1ccccc1NC(=O)CSC(=O)NNC(=O)[C@@H](Cc1c[nH]c...       CTSL1    NaN
# 207      CCC1CCC2OC3(CC[C@@H](C)C(C[C@H](C)O)O3)[C@H](C...      ATP5L2    NaN
# 452      CCC(O)(CC)\C=C\CC(C)C1=CC[C@@H]2[C@]1(C)CCC\C2...         VDR    NaN

# %%
list(l[l['string'].isnull()].index)
# Out:
# [10, 43, 178, 207, 452]

# %%
sum(l.index == 178)
# Out:
# 1

# %%
ctrp_ranker.to_csv('../data/ctrp_drugranker/drugs_with_target.csv')

# %%
'VDR' in ppi_data.index
# Out:
# False

# %%
l[l['prot_target']=='CTSL1']['prot_target'] = 'CTSL'
# Out:
# C:\Users\sarme\AppData\Local\Temp\ipykernel_3184\1500459843.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   l[l['prot_target']=='CTSL1']['prot_target'] = 'CTSL'

# %%
l[l['prot_target']=='CTSL1']['prot_target'][178] = 'CTSL'
# Out:
# C:\Users\sarme\AppData\Local\Temp\ipykernel_3184\2046143455.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   l[l['prot_target']=='CTSL1']['prot_target'][178] = 'CTSL'

# %%
l[l['prot_target']=='CTSL1']
# Out:
#          master_cpd_id      cpd_name cpd_status  \
# level_0
# 178             411731  SID 26681509      probe
#
#                                                 cpd_smiles prot_target string
# level_0
# 178      CCc1ccccc1NC(=O)CSC(=O)NNC(=O)[C@@H](Cc1c[nH]c...       CTSL1    NaN

# %%
l.at[178, 'prot_target'] = 'CTSL'

# %%
l['prot_target'][178]
# Out:
# 'CTSL'

# %%
l
# Out:
#          master_cpd_id                       cpd_name cpd_status  \
# level_0
# 3                17712                          ML006      probe
# 4                18311            Bax channel blocker      probe
# 6                23151                      tretinoin        FDA
# 6                23151                      tretinoin        FDA
# 6                23151                      tretinoin        FDA
# ...                ...                            ...        ...
# 541             689136  BRD9876:MK-1775 (4:1 mol/mol)      probe
# 542             689506                  BRD-K30748066      probe
# 543             705300                     linsitinib   clinical
# 543             705300                     linsitinib   clinical
# 544             710154                         AT-406      probe
#
#                                                 cpd_smiles prot_target  \
# level_0
# 3                 C1CN(CCO1)c1nnc(-c2ccccc2)c(n1)-c1ccccc1       S1PR3
# 4                OC(CN1CCNCC1)Cn1c2ccc(Br)cc2c2cc(Br)ccc12         BAX
# 6                 CC(=CC=CC(=CC(=O)O)C)C=CC1=C(C)CCCC1(C)C        RARA
# 6                 CC(=CC=CC(=CC(=O)O)C)C=CC1=C(C)CCCC1(C)C        RARB
# 6                 CC(=CC=CC(=CC(=O)O)C)C=CC1=C(C)CCCC1(C)C        RARG
# ...                                                    ...         ...
# 541      CC(C)(C)c1ccc2cc(C#N)c(cc2c1)C#N.CN1CCN(CC1)c1...        WEE1
# 542          Cc1c(sc(=O)n1C)-c1ccnc(Nc2ccc(cc2)N2CCNCC2)n1        CDK9
# 543      CC1(O)CC(C1)c2nc(c3ccc4ccc(nc4c3)c5ccccc5)c6c(...       IGF1R
# 543      CC1(O)CC(C1)c2nc(c3ccc4ccc(nc4c3)c5ccccc5)c6c(...        INSR
# 544      CNC(C)C(=O)NC1CN(CCC2CCC(N2C1=O)C(=O)NC(c3cccc...        XIAP
#
#                        string
# level_0
# 3        9606.ENSP00000365006
# 4        9606.ENSP00000293288
# 6        9606.ENSP00000254066
# 6        9606.ENSP00000332296
# 6        9606.ENSP00000388510
# ...                       ...
# 541      9606.ENSP00000402084
# 542      9606.ENSP00000362361
# 543      9606.ENSP00000497069
# 543      9606.ENSP00000303830
# 544      9606.ENSP00000360242
#
# [873 rows x 6 columns]

# %%
l.at[178, 'string'] = ppi_data[ppi_data.index == 'CTSL']['#string_protein_id']['CTSL']

# %%
ppi_data[ppi_data.index == 'CTSL']['#string_protein_id']['CTSL']
# Out:
# '9606.ENSP00000345344'

# %%
l.at[178, 'string']
# Out:
# '9606.ENSP00000345344'

# %%
l
# Out:
#          master_cpd_id                       cpd_name cpd_status  \
# level_0
# 3                17712                          ML006      probe
# 4                18311            Bax channel blocker      probe
# 6                23151                      tretinoin        FDA
# 6                23151                      tretinoin        FDA
# 6                23151                      tretinoin        FDA
# ...                ...                            ...        ...
# 541             689136  BRD9876:MK-1775 (4:1 mol/mol)      probe
# 542             689506                  BRD-K30748066      probe
# 543             705300                     linsitinib   clinical
# 543             705300                     linsitinib   clinical
# 544             710154                         AT-406      probe
#
#                                                 cpd_smiles prot_target  \
# level_0
# 3                 C1CN(CCO1)c1nnc(-c2ccccc2)c(n1)-c1ccccc1       S1PR3
# 4                OC(CN1CCNCC1)Cn1c2ccc(Br)cc2c2cc(Br)ccc12         BAX
# 6                 CC(=CC=CC(=CC(=O)O)C)C=CC1=C(C)CCCC1(C)C        RARA
# 6                 CC(=CC=CC(=CC(=O)O)C)C=CC1=C(C)CCCC1(C)C        RARB
# 6                 CC(=CC=CC(=CC(=O)O)C)C=CC1=C(C)CCCC1(C)C        RARG
# ...                                                    ...         ...
# 541      CC(C)(C)c1ccc2cc(C#N)c(cc2c1)C#N.CN1CCN(CC1)c1...        WEE1
# 542          Cc1c(sc(=O)n1C)-c1ccnc(Nc2ccc(cc2)N2CCNCC2)n1        CDK9
# 543      CC1(O)CC(C1)c2nc(c3ccc4ccc(nc4c3)c5ccccc5)c6c(...       IGF1R
# 543      CC1(O)CC(C1)c2nc(c3ccc4ccc(nc4c3)c5ccccc5)c6c(...        INSR
# 544      CNC(C)C(=O)NC1CN(CCC2CCC(N2C1=O)C(=O)NC(c3cccc...        XIAP
#
#                        string
# level_0
# 3        9606.ENSP00000365006
# 4        9606.ENSP00000293288
# 6        9606.ENSP00000254066
# 6        9606.ENSP00000332296
# 6        9606.ENSP00000388510
# ...                       ...
# 541      9606.ENSP00000402084
# 542      9606.ENSP00000362361
# 543      9606.ENSP00000497069
# 543      9606.ENSP00000303830
# 544      9606.ENSP00000360242
#
# [873 rows x 6 columns]

# %%
l = l.dropna(subset = ['string'])
# Out:
#          master_cpd_id                       cpd_name cpd_status  \
# level_0
# 3                17712                          ML006      probe
# 4                18311            Bax channel blocker      probe
# 6                23151                      tretinoin        FDA
# 6                23151                      tretinoin        FDA
# 6                23151                      tretinoin        FDA
# ...                ...                            ...        ...
# 541             689136  BRD9876:MK-1775 (4:1 mol/mol)      probe
# 542             689506                  BRD-K30748066      probe
# 543             705300                     linsitinib   clinical
# 543             705300                     linsitinib   clinical
# 544             710154                         AT-406      probe
#
#                                                 cpd_smiles prot_target  \
# level_0
# 3                 C1CN(CCO1)c1nnc(-c2ccccc2)c(n1)-c1ccccc1       S1PR3
# 4                OC(CN1CCNCC1)Cn1c2ccc(Br)cc2c2cc(Br)ccc12         BAX
# 6                 CC(=CC=CC(=CC(=O)O)C)C=CC1=C(C)CCCC1(C)C        RARA
# 6                 CC(=CC=CC(=CC(=O)O)C)C=CC1=C(C)CCCC1(C)C        RARB
# 6                 CC(=CC=CC(=CC(=O)O)C)C=CC1=C(C)CCCC1(C)C        RARG
# ...                                                    ...         ...
# 541      CC(C)(C)c1ccc2cc(C#N)c(cc2c1)C#N.CN1CCN(CC1)c1...        WEE1
# 542          Cc1c(sc(=O)n1C)-c1ccnc(Nc2ccc(cc2)N2CCNCC2)n1        CDK9
# 543      CC1(O)CC(C1)c2nc(c3ccc4ccc(nc4c3)c5ccccc5)c6c(...       IGF1R
# 543      CC1(O)CC(C1)c2nc(c3ccc4ccc(nc4c3)c5ccccc5)c6c(...        INSR
# 544      CNC(C)C(=O)NC1CN(CCC2CCC(N2C1=O)C(=O)NC(c3cccc...        XIAP
#
#                        string
# level_0
# 3        9606.ENSP00000365006
# 4        9606.ENSP00000293288
# 6        9606.ENSP00000254066
# 6        9606.ENSP00000332296
# 6        9606.ENSP00000388510
# ...                       ...
# 541      9606.ENSP00000402084
# 542      9606.ENSP00000362361
# 543      9606.ENSP00000497069
# 543      9606.ENSP00000303830
# 544      9606.ENSP00000360242
#
# [869 rows x 6 columns]

# %%
l.to_csv('../data/ctrp_drugranker/drugs_with_target.csv')
